# %% [markdown]
# # End-of-Module Assessment 1

# %% [markdown]
# ## Instructions
#
# Please read and follow these instructions and specifications carefully.
#
# 1. This test is available from July 22 to 11:59 PM of July 27. We will only grade this test after July 27, and we will only grade it once.
# 2. This test covers Modules 2 to 4. At this point in the course, you are expected to be familiar enough with Python to use the concepts from these modules with finesse.
# 3. Unless otherwise specified, you are not allowed to use any non-standard (i.e., not in the standard library) modules for this test. We must be strict about this on principle. For example, if you use NumPy or Pandas without permission on problems which ask you to process data, we reserve the right to give your answer no credit. If you are unsure whether you are allowed to use a library, ask. (Yes, you can use the csv and json libraries.)
# 4. Answers to problems that are hard-coded, done in another program such as Excel, or go against the learning outcomes in any other manner will be given no credit. If you are unsure whether your approach to a problem goes against the learning outcomes, ask.
# 5. You are encouraged to use only the provided code cell for each number. However, if you _need_ more cells, you may add them. If you do add more cells, make sure to label them very clearly. Code cells that are not clearly labelled will not be checked.
# 6. If you are asked to output files, please write them all to the `output` folder, even if we forget to specify the ./output prefix.
# 7. If we ask you to use an input file, please find the file in the appropriate section's folder. If it is not there, let us know.
#
# Some notes:
# 1. Joe made some of these items, and Joben made the others. The items will likely have different conventions in the context/briefs. Please follow them carefully anyway.

# %% [markdown]
# ## Section 1: Rudimentary Data Processing

# %% [markdown]
# ### Context
#
# One extremely common form of data is the data shared between applications. Nowadays, when applications talk to each other, they send data in the form of JSON using Hypertext Transfer Protocol (HTTP). You will learn more about this in the next module.
#
# For this section, you are to process data from Twitter's API. The results of several requests to Twitter's API about tweets with the keyword "SONA" have been pre-saved in a `.json` file called `./section1/tweets.json`. Please run the following cell to ensure that the file loads properly.

# %%
# execute this cell to load the file

import json
# If the tweets do not load properly, change this path as necessary.
tweets_file = './section1/tweets.json'

with open(tweets_file, "r") as json_file:
    tweets = json.loads(json_file.read())

# Print contents of tweets to make sure things are okay.
print(tweets)
# Out:
# [{'created_at': 'Tue Jul 28 03:25:35 +0000 2020', 'id': 1287952316029521920, 'id_str': '1287952316029521920', 'full_text': 'RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 130], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'watchmejayjay', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'id': 2148463897, 'id_str': '2148463897', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1334271631, 'id_str': '1334271631', 'name': 'kai', 'screen_name': '_kyladel', 'location': 'Alaska', 'description': 'yessir i listen to hayley kiyoko', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1490, 'friends_count': 551, 'listed_count': 3, 'created_at': 'Sun Apr 07 14:38:46 +0000 2013', 'favourites_count': 46915, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 74517, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1334271631/1589814512', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jul 27 11:10:15 +0000 2020', 'id': 1287706865581752321, 'id_str': '1287706865581752321', 'full_text': 'Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 111], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2148463897, 'id_str': '2148463897', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'screen_name': 'watchmejayjay', 'location': '', 'description': "I'm not your Bio teacher", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1128, 'friends_count': 388, 'listed_count': 0, 'created_at': 'Tue Oct 22 06:34:00 +0000 2013', 'favourites_count': 6250, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5642, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twim ...

# %% [markdown]
# ### 1.1
#
# Print out the number of tweets.

# %%
# CODE CELL

# CODE START
print(len(tweets))
# CODE END
# Out:
# 100

# %% [markdown]
# ### 1.2
#
# Create a list variable called `tweet_texts` that contains the text of the tweets contained in `tweets`.
#
# Afterwards, print `tweet_texts`.

# %%
# CODE CELL

# CODE START
tweet_texts = []

for tweet in tweets:
    tweet_texts.append(tweet["full_text"])
    
print(tweet_texts)
# CODE END

# The output should look like this.
# Out:
# ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 
入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @CIRE41: Sabi ng mga wokes, hindi raw sila na-inspire sa SONA.\nAkala ko ba may panawagan sila na i-boycott ang pakikinig?\n\nAnyare?', 'RT @Plaridel_DLSU: Ngayong araw isasagawa ang ikalimang SONA na nagkaroon ng mga pagbabago dahil sa pandemyang idinulot ng COVID-19. #SONA2…', 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @JethroGamez: Tapos na ang SONA trends. Balik na tayo sa normal Twitter.\n\nAnd most especially, si Duterte pa rin ang Pangulo ng Republik…', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @SB19TrendsPH: [TAG UPDATE]\n\nTo give way to discussions related to SONA 2020 held earlier this afternoon, we would like to request to dr…', 'RT @boymejo: Replay of my YouTube livestream on my reaction to the SONA esp with regard to #FranklinDrilon https://t.co/7acRwA6X6Q', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Difficult step .\nMere liye kar lega rohit....me kar lunga sona ko step pasand he 🙂.\n\n#KahaanHumKahaanTum #Ronakshi \n #KarPika #KaranVGrover #DipikaKakar \nTum jao ghar pe sona mujhe sikha degi 😂😂😂 \nMujhe maza aaya tha 😂😂 https://t.co/aqRFuujs0I', 'RT @itsyaboiraff: Joseph Morong listening while typing the minutes of SONA 2020. https://t.co/NQ0ZQWKJ2d', "This health emergency stretched the government’s resources to its limits. In response, the Office of the President worked closely with Congress for the quick passage of the Bayanihan to Heal as One Act.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Nanga @ThalaAjith_FC  tag sona tha tweets poduvom . \n\nNanga @ThalaAjith_ ...

# %% [markdown]
# ### 1.4
#
# We will now perform a very simple word count on the texts.
#
# We have provided a dictionary called `words_dict`. Your code in the next cell should process the tweets such that `words_dict` will contain key-value pairs where the key is a unique word and where the value is the number of times the word appears across all of the texts.
#
# For each text, remove the characters contained in the following string:
#
# `"&$@[].,'#()-\"!?’_"`
#
# Please ignore the newline (`\n`) character.

# %%
# CODE CELL
words_dict = {}
remove_chars = "&$@[].,'#()-\"!?’_"

# CODE START
# Change tweets to correct format
for tweet in tweet_texts:
    tweet = tweet.replace("\n", " ")
    for word in tweet.split(" "):
        for special_char in remove_chars:
            word = word.replace(special_char, "")
        uppercase_word = word.upper()
        
        # Counter
        if uppercase_word == "":
            pass
        elif uppercase_word in words_dict:
            words_dict[uppercase_word] += 1
        else:
            words_dict[uppercase_word] = 1
# CODE END

# Your output should look like this.
print(words_dict)
# Out:
# {'RT': 53, 'HEROANGEL17:': 1, 'SONA': 65, 'STATE': 4, 'OF': 30, 'NO': 2, 'ACCOMPLISHMENT': 1, '🤭✊': 1, 'BENOKCASTILLO:': 1, 'IKUMPARA': 1, 'ANG': 20, 'SA': 34, 'TESTIMONYA': 1, 'NI': 7, 'NANAY': 1, 'HASHTAGNIKKO13:': 1, 'DI': 4,
# %% [markdown]
# ### 1.5
#
# Now, we would like to have a list of words and counts sorted by count in descending order.
#
# Define a new list variable named `words_list` containing **tuples**, where each tuple is as follows:
#
# `(word, count)`
#
# Print the contents of `words_list`.
#
# Sample output is provided below.

# %%
# CODE CELL

# CODE START
words_list = []
for key in words_dict:
    words_list.append((key,words_dict[key]))
# CODE END

# The output should look like this. 
print(words_list)
# Out:
# [('RT', 53), ('HEROANGEL17:', 1), ('SONA', 65), ('STATE', 4), ('OF', 30), ('NO', 2), ('ACCOMPLISHMENT', 1), ('🤭✊', 1), ('BENOKCASTILLO:', 1), ('IKUMPARA', 1), ('ANG', 20), ('SA', 34), ('TESTIMONYA', 1), ('NI', 7), ('NANAY', 1), ('HASHTAGNIKKO13:', 1), ('DI', 4), ('KO', 4), ('NAKITA', 2), ('YUNG', 4), ('SONA😢😢', 1), ('HAYAAN', 1), ('NA', 19), ('NGA', 1), ('RIN', 4), ('NAMAN', 3), ('NILA', 1), ('TAYO', 2), ('NAKIKITA', 1), ('RIA', 1), ('ATAYDE', 1), ('SENDS', 1), ('STRONG', 1), ('MESSAGE', 2), ('SHARES', 2), ('ANGRY', 1), ('QUOTE', 1), ('BEFORE', 3), ('PRES', 4), ('DUTERTES', 10), ('5TH', 13), ('RIAATAYDE', 1), ('SONA2020', 4), ('READ', 1), ('MORE:', 1), ('HTTPS://TCO/WTFCJZZE1L', 1), ('MAY', 6), ('I', 6), ('AGAIN', 2), ('REITERATE', 1), ('MY', 8), ('THANKS', 1), ('TO', 36), ('YOU', 4), ('THE', 55), ('MEN', 1), ('AND', 14), ('WOMEN', 1), ('CONGRESS', 3), ('FOR', 11), ('EFFORT', 1), ('INVESTED', 1), ('INTO', 1), ('PASSING', 1), ('THAT', 7), ('LAW', 2), ('PRESIDENT', 8), ('RODRIGO', 4), ('ROA', 4), ('KBROSAS:', 1), ('JOKE', 1), ('AKO', 2), ('ABOUT', 2), ('KASO', 1), ('WAG', 2), ('LANG', 3), ('PALA', 2), ('KC', 1), ('WALANG', 2), ('KWENTA', 1), ('😜', 1), ('CHARLISCTEX:', 1), ('DUTERTE', 10), ('READING', 1), ('HIS', 5), ('SCRIPT', 1), ('HTTPS://TCO/Q9EER67BIZ', 1), ('IAMKARENDAVILA:', 1), ('OKAY', 1), ('CLEARLY', 1), ('SENATOR', 1), ('FRANKLIN', 2), ('DRILON', 2), ('IS', 5), ('IN', 11), ('PRESIDENTS', 2), ('CONSCIOUSNESS', 1), ('MENTIONING', 1), ('HIM', 3), ('CALLS', 1), ('HIM…', 1), ('ITSACSLIFE:', 1), ('FACT', 1), ('THIS', 7), ('YEARS', 1), ('WONT', 2), ('REACH', 2), ('WHOLE', 1), ('NATION', 2), ('BECAUSE', 1), ('ONLY', 2), ('STATION', 1), ('CAN', 2), ('EVERYONE', 3), ('NATION
# %% [markdown]
# ### 1.6
#
# Sort the list by count (which is the second element of each tuple) in descending (or reverse) order.
#
# Print the contents of the newly-sorted list `words_list`.
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START
def take_count(x):
    return(x[1])

words_list.sort(key=take_count, reverse=True)
print(words_list)
# CODE END

# The output should look like this.
print(words_list)
# Out:
# [('SONA', 65), ('THE', 55), ('RT', 53), ('TO', 36), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('AND', 14), ('NG', 14), ('5TH', 13), ('MGA', 12), ('FOR', 11), ('IN', 11), ('DUTERTES', 10), ('DUTERTE', 10), ('WE', 9), ('MY', 8), ('PRESIDENT', 8), ('WITH', 8), ('NI', 7), ('THAT', 7), ('THIS', 7), ('COVID19', 7), ('2020', 7), ('MAY', 6), ('I', 6), ('A', 6), ('AMP;', 6), ('HIS', 5), ('IS', 5), ('PA', 5), ('UP', 5), ('ON', 5), ('TAG', 5), ('STATE', 4), ('DI', 4), ('KO', 4), ('YUNG', 4), ('RIN', 4), ('PRES', 4), ('SONA2020', 4), ('YOU', 4), ('RODRIGO', 4), ('ROA', 4), ('STUDENT', 4), ('THEY', 4), ('SI', 4), ('WAY', 4), ('YA', 4), ('KA', 4), ('FIRST', 4), ('NAMAN', 3), ('BEFORE', 3), ('CONGRESS', 3), ('LANG', 3), ('HIM', 3), ('EVERYONE', 3), ('COUNCIL', 3), ('FROM', 3), ('SILA', 3), ('ARAW', 3), ('ONE', 3), ('WOULD', 3), ('LIKE', 3), ('THA', 3), ('ITS', 3), ('KHARAASONA', 3), ('AT', 3), ('SONAGKAISA', 3), ('ME', 3), ('HER', 3), ('OWN', 3), ('RAPPLERDOTCOM:', 3), ('DAPAT', 3), ('GLOBE', 3), ('IF', 3), ('DURING', 3), ('PRESS', 3), ('NO', 2), ('NAKITA', 2), ('TAYO', 2), ('MESSAGE', 2), ('SHARES', 2), ('AGAIN', 2), ('LAW', 2), ('AKO', 2), ('ABOUT', 2), ('WAG', 2), ('PALA', 2), ('WALANG', 2), ('FRANKLIN', 2), ('DRILON', 2), ('PRESIDENTS', 2), ('WONT', 2), ('REACH', 2), ('NATION', 2), ('ONLY', 2), ('CAN', 2), ('MABUTI', 2), ('PERO', 2), ('GMANEWS:', 2), ('WAR', 2), ('AFTER', 2), ('TOWERNAMBA:', 2), ('【ジェジュン】', 2), ('COVERS', 2), ('GROUPS', 2), ('HAVE', 2), ('DONT', 2), ('SABI', 2), ('HINDI', 2), ('BA', 2), ('NGAYONG', 2), ('LA', 2), ('PERSONA', 2), ('QUE', 2), ('TE', 2), ('TAPOS', 2), ('PANGULO', 2), ('GET', 2), ('SAME',
# [('SONA', 65), ('THE', 55), ('RT', 53), ('TO', 36), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('AND', 14), ('NG', 14), ('5TH', 13), ('MGA', 12), ('FOR', 11), ('IN', 11), ('DUTERTES', 10), ('DUTERTE', 10), ('WE', 9), ('MY', 8), ('PRESIDENT', 8), ('WITH', 8), ('NI', 7), ('THAT', 7), ('THIS', 7), ('COVID19', 7), ('2020', 7), ('MAY', 6), ('I', 6), ('A', 6), ('AMP;', 6), ('HIS', 5), ('IS', 5), ('PA', 5), ('UP', 5), ('ON', 5), ('TAG', 5), ('STATE', 4), ('DI', 4), ('KO', 4), ('YUNG', 4), ('RIN', 4), ('PRES', 4), ('SONA2020', 4), ('YOU', 4), ('RODRIGO', 4), ('ROA', 4), ('STUDENT', 4), ('THEY', 4), ('SI', 4), ('WAY', 4), ('YA', 4), ('KA', 4), ('FIRST', 4), ('NAMAN', 3), ('BEFORE', 3), ('CONGRESS', 3), ('LANG', 3), ('HIM', 3), ('EVERYONE', 3), ('COUNCIL', 3), ('FROM', 3), ('SILA', 3), ('ARAW', 3), ('ONE', 3), ('WOULD', 3), ('LIKE', 3), ('THA', 3), ('ITS', 3), ('KHARAASONA', 3), ('AT', 3), ('SONAGKAISA', 3), ('ME', 3), ('HER', 3), ('OWN', 3), ('RAPPLERDOTCOM:', 3), ('DAPAT', 3), ('GLOBE', 3), ('IF', 3), ('DURING', 3), ('PRESS', 3), ('NO', 2), ('NAKITA', 2), ('TAYO', 2), ('MESSAGE', 2), ('SHARES', 2), ('AGAIN', 2), ('LAW', 2), ('AKO', 2), ('ABOUT', 2), ('WAG', 2), ('PALA', 2), ('WALANG', 2), ('FRANKLIN', 2), ('DRILON', 2), ('PRESIDENTS', 2), ('WONT', 2), ('REACH', 2), ('NATION', 2), ('ONLY', 2), ('CAN', 2), ('MABUTI', 2), ('PERO', 2), ('GMANEWS:', 2), ('WAR', 2), ('AFTER', 2), ('TOWERNAMBA:', 2), ('【ジェジュン】', 2), ('COVERS', 2), ('GROUPS', 2), ('HAVE', 2), ('DONT', 2), ('SABI', 2), ('HINDI', 2), ('BA', 2), ('NGAYONG', 2), ('LA', 2), ('PERSONA', 2), ('QUE', 2), ('TE', 2), ('TAPOS', 2), ('PANGULO', 2), ('GET', 2), ('SAME', 2), ('PASSAGE', 2), ('BAYANIHAN', 2), ('AS', 2), ('ACT', 2), ('WHICH', 2), ('RESPONSE', 2), ('AGAINST', 2), ('PANDEMIC', 2), ('UPDATE', 2), ('GIVE', 2), ('DISCUSSIONS', 2), ('RELATED', 2), ('HELD', 2), ('EARLIER', 2), ('AFTERNOON', 2), ('REQU
# %% [markdown]
# ### 1.7
#
# Print out the top 5 words (based on count).
#
# Take note of the formatting below (i.e. one line per print output).
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START
index = 0
while index <= 4:
    print(index+1, words_list[index])
    index += 1
# CODE END

# The output should look like this.
# Out:
# 1 ('SONA', 65)
# 2 ('THE', 55)
# 3 ('RT', 53)
# 4 ('TO', 36)
# 5 ('SA', 34)

# %% [markdown]
# ### 1.8
#
# Write a new csv file `./output/wordcount.csv` with format like so:
#
# `word,count`
# `SONA,65`
# `THE,55`
# `RT,53`
# `TO,36`
# `SA,34`
# `...`

# %%
# CODE CELL
import csv
import json

# CODE START 
header = ['word','count']

with open ('./output/wordcount.csv', 'w') as csvfile:
    csvwriter = csv.writer (csvfile)
    csvwriter.writerow(header)
    csvwriter.writerows(words_list) 
# CODE END

# %% [markdown]
# Perform a `diff` or `fc` operation between your output file and the file named `wordcount-test.csv` which should be included in `section1`. Make sure there are no differences.
#
# **IMPORTANT**: Please make sure that you submit wordcount.csv along with the rest of your files.

# %% [markdown]
# ## Section 2: Reports for the Registrar

# %% [markdown]
# ### Context
#
# Data is rarely in the form in which you want it. In this section of the assessment, you are doing consulting work for Ateneo's Office of the Registrar. They managed to collect the enlistment data for 4410 students through a Google Form. The form was not designed in such a way that the collected data is immediately usable, so they hired you to process their raw data into more appropriate forms.
#
# Please run the following cell to load the file.

# %%
# execute this cell to load the file
import json

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)
    
# Print the first few items of this file to check that it worked properly
# Please infer and understand the schema of this file.
print(student_data[:3])
# Out:
# [{'enlistment': [{'course code': 'UK 60', 'section': 'A'}, {'course code': 'GF 24', 'section': 'B'}, {'course code': 'ME 40', 'section': 'B'}, {'course code': 'VY 44', 'section': 'D'}, {'course code': 'EN 94', 'section': 'B'}], 'id': '201001', 'paid': True, 'school': 'SOSE', 'year level': 2}, {'enlistment': [{'course code': 'EQ 61', 'section': 'D'}, {'course code': 'UZ 22', 'section': 'B'}, {'course code': 'KS 36', 'section': 'B'}, {'course code': 'VH 63', 'section': 'A'}, {'course code': 'IW 81', 'section': 'C'}], 'id': '211002', 'paid': True, 'school': 'JGSOM', 'year level': 1}, {'enlistment': [{'course code': 'WE 15', 'section': 'D'}, {'course code': 'ZP 68', 'section': 'A'}, {'course code': 'GI 78', 'section': 'A'}, {'course code': 'GK 72', 'section': 'C'}, {'course code': 'FA 24', 'section': 'D'}, {'course code': 'UJ 28', 'section': 'A'}], 'id': '201003', 'paid': True, 'school': 'JGSOM', 'year level': 2}]

# %% [markdown]
# ### 2.1
#
# The first report the Registrar needs is a summary of all courses being offered. They want this report in the form of a **dictionary** whose keys are unique course codes and whose values are dictionaries with a single key-value pair describing the sections available for that course code.
#
# Here is the schema of the desired output:
#
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: {`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"sections": [sections]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}`
# `}`
#
# A dictionary called `courses` is provided to you in the following cell. Using `student_data`, populate `courses` with the data the Registrar needs.
#
# Dump this file as `./output/courses-output.json`.
#
# Additional specifications:
# 1. Sort the list of sections alphabetically.
#
# Sample output is provided in `./section2/courses-sample-output.json`.

# %%
# CODE CELL
import json
courses = {}

# CODE START
# Put all unique courses to courses_only
courses_list = []

for student in student_data:
    index = 0
    while index < len(student['enlistment']):
        courses_list.append(student['enlistment'][index]['course code'])
        index += 1
courses_only = ((set(courses_list)))

# Find all unique sections for each respective course
for course in courses_only:
    sections = []
    i = 0
    for student in student_data:
        j = 0
        while j < len(student['enlistment']):
            if (student_data[i]['enlistment'][j]['course code'])== course:
                sections.append(student_data[i]['enlistment'][j]['section'])
                j += 1
            else:
                j += 1
        i += 1
    sections = list(sorted(set(sections)))
    # Place contents to courses
    courses[course]={'sections':sections}

# Writing Python data into JSON file
with open('./output/courses-output.json', 'w') as courses_file:
    json.dump(courses, courses_file, indent = 4)

# CODE END

# The output should look like this.
print(courses)
# Out:
# {'KD 33': {'sections': ['A']}, 'GM 72': {'sections': ['A']}, 'ZP 68': {'sections': ['A']}, 'BN 85': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'ZB 82': {'sections': ['A']}, 'ME 40': {'sections': ['A', 'B', 'C']}, 'TT 59': {'sections': ['A', 'B']}, 'KD 10': {'sections': ['A', 'B', 'C']}, 'SN 88': {'sections': ['A']}, 'VY 44': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'FX 96': {'sections': ['A']}, 'MC 25': {'sections': ['A', 'B']}, 'RT 81': {'sections': ['A']}, 'GF 24': {'sections': ['A', 'B', 'C']}, 'EQ 61': {'sections': ['A', 'B', 'C', 'D']}, 'VS 18': {'sections': ['A']}, 'HK 84': {'sections': ['A']}, 'IW 81': {'sections': ['A', 'B', 'C']}, 'WE 15': {'sections': ['A', 'B', 'C', 'D']}, 'GV 12': {'sections': ['A']}, 'YB 54': {'sections': ['A', 'B', 'C', 'D']}, 'FZ 18': {'sections': ['A']}, 'YS 74': {'sections': ['A', 'B', 'C']}, 'UK 70': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'GI 78': {'sections': ['A']}, 'FA 24': {'sections': ['A', 'B', 'C', 'D']}, 'HW 19': {'sections': ['A']}, 'YD 55': {'sections': ['A', 'B', 'C', 'D']}, 'OG 37': {'sections': ['A', 'B', 'C', 'D']}, 'TS 66': {'sections': ['A']}, 'SE 79': {'sections': ['A', 'B', 'C', 'D']}, 'LV 41': {'sections': ['A', 'B', 'C', 'D']}, 'VC 62': {'sections': ['A', 'B', 'C']}, 'UJ 28': {'sections': ['A', 'B', 'C']}, 'AI 41': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'MU 79': {'sections': ['A', 'B']}, 'QR 51': {'sections': ['A']}, 'ZJ 82': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'VH 63': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'KC 22': {'sections': ['A', 'B', 'C', 'D']}, 'EN 94': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'UK 60': {'sections': ['A']}, 'AX 43': {'sections': ['A']}, 'KS 36': {'sections': ['A', 'B', 'C']}, 'YQ 49': {'sections': ['A', 'B']}, 'UZ 22': {'sections': ['A', 'B', 'C']}, 'PG 71': {'sections': ['A', 'B', 'C']}, 'GK 72': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'LJ 29': {'sections': ['A', 'B']}}

# %% [markdown]
# ### 2.2
#
# The second report the Registrar needs is a _class list_ of every section. They want this report in the form of a **dictionary** whose keys are the course code and whose values are dictionaries describing the sections of that course code. Each section dictionary has two key-value pairs:
# 1. Key: "section"; Value: Section letter
# 2. Key: "class list"; Value: [id numbers]
#
# Here is the schema of the desired output:
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: [{`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"section": section_letter,`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"class list": [id_numbers]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}]`
# `}`
#
# A dictionary called `class_lists` is provided to you. Using `student_data`, populate `class_lists` with the data that the Registrar needs.
#
# Dump this file as `./output/class-lists.json`.
#
# Additional specifications:
# 1. Sort the list of ID numbers. No need to convert them to int, just sort them in place with `.sort()`.
# 2. Do not reference the `courses` dictionary from Item 2.1 directly. This cell should be able to run independently of Item 2.1. You may, however, reuse your code by copy-pasting it here if you find that it will help.
#
# Sample output is provided in `./section2/class-lists-sample-output.json`.

# %%
# CODE CELL
import json
class_lists = {}

# CODE START
# START COPY 2.1
courses = {}
# Put all unique courses to courses_only
courses_list = []

for student in student_data:
    index = 0
    while index < len(student['enlistment']):
        courses_list.append(student['enlistment'][index]['course code'])
        index += 1
courses_only = ((set(courses_list)))

# Find all unique sections for each respective course
for course in courses_only:
    sections = []
    i = 0
    for student in student_data:
        j = 0
        while j < len(student['enlistment']):
            if (student_data[i]['enlistment'][j]['course code'])== course:
                sections.append(student_data[i]['enlistment'][j]['section'])
                j += 1
            else:
                j += 1
        i += 1
    sections = list(sorted(set(sections)))
    # Place contents to courses
    courses[course]={'sections':sections}
#END COPY 2.1

# Get sections to place in class_lists
for course in courses:
    for section in courses[course]['sections']:
        if course in class_lists:
            class_lists[course].append({'section':section,'class list':[]})
        else:
            class_lists[course] = [{'section':section,'class list':[]}]
            
# Get respective class lists for each section
i = 0
for student in student_data:
    j = 0
    for subject in student_data[i]['enlistment']:
        for course in class_lists:
            k = 0
            for section in class_lists[course]:
                student_course = student_data[i]['enlistment'][j]['course code']
                student_section = student_data[i]['enlistment'][j]['section']
                id_number = student_data[i]['id']
                if student_course == course and student_section == class_lists[course][k]['section']:
                    class_lists[course][k]['class list'].append(id_number)
                    class_lists[course][k]['class list'].sort()
                else:
                    pass
                k += 1
        j += 1
    i += 1

# Writing Python data into JSON file
with open('./output/class-lists.json', 'w') as class_list_file:
    json.dump(class_lists, class_list_file, indent = 4)
    
# CODE END

print(class_lists)
# Out:
# {'KD 33': [{'section': 'A', 'class list': ['201032', '201039', '201042', '201052', '201064', '201067', '201068', '201073', '201115', '201135', '201139', '201170', '201213', '201218', '201231', '201242', '201249', '201265', '201272', '201275', '201278', '201285', '201303', '201305', '201312', '201319', '201335', '201336', '201361', '201365', '201375', '201442', '201449', '201471', '201487', '201493', '201503', '201551', '201571', '201576', '201662', '201675', '201679', '201699', '201701', '201702', '201709', '201715', '201730', '201739', '201775', '201795', '201802', '201827', '201829', '201834', '201859', '201867', '201887', '201895', '201907', '201909', '201924', '201929', '201941', '201990', '201993', '202021', '202035', '202037', '202059', '202071', '202087', '202104', '202184', '202189', '202204', '202218', '202249', '202251', '202293', '202295', '202307', '202312', '202315', '202337', '202346', '202349', '202362', '202369', '202382', '202411', '202422', '202428', '202436', '202460', '202503', '202518', '202526', '202551', '202554', '202560', '202572', '202592', '202605', '202608', '202676', '202679', '202715', '202735', '202773', '202792', '202862', '202863', '202871', '202884', '202950', '202986', '202993', '203006', '203009', '203016', '203054', '203058', '203091', '203099', '203102', '203147', '203153', '203185', '203190', '203196', '203198', '203213', '203236', '203239', '203245', '203270', '203278', '203284', '203293', '203302', '203306', '203312', '203330', '203331', '203397', '203403', '203437', '203439', '203440', '203456', '203519', '203536', '203579', '203589', '203593', '203600', '203614', '203616', '203624', '203633', '203644', '203670', '203685', '203695', '203707', '203721', '203747', '203801', '203802', '203804', '203827', '203872', '203877', '203912', '203946', '204002', '204041', '204047', '204050', '204052', '204082', '204095', '204108', '204174', '204175', '204199', '204230', '204238', '204245', '204272', '204317', '204346', '204390', '204394', '204406', '204407', '204417', '204429', '204479', '204486', '204521', '204533', '204575', '204582', '204597', '204639', '204653', '204662', '204683', '204711', '204722', '204742', '204745', '204746', '204775', '204779', '204824', '204838', '204842', '204844', '204853', '204885', '204906', '204919', '204938', '204947', '204987', '205021', '205025', '205063', '205079', '205081', '205098', '205104', '205135', '205169', '205176', '205204', '205230', '205264', '205307', '205320', '205329', '205340', '205347', '205357', '205359', '205386', '211034', '211037', '211060', '211098', '211100', '211126', '211137', '211148', '211164', '211182', '211221', '211240', '211243', '211245', '211252', '211263', '211268', '211271', '211274', '211276', '211284', '211310', '211314', '211344', '211349', '211353', '211401', '211403', '211405', '211452', '211454', '211490', '211509', '211535', '211553', '211561', '211602', '211656', '211666', '211692', '211717', '211723', '211728', '211742', '211745', '211749', '211770', '211838', '211844', '211847', '211906', '211935', '211956', '211987', '212020', '212030', '212042', '212050', '212057', '212066', '212079', '212081', '212083', '212094', '212106', '212120', '212138', '212151', '212176', '212180', '212187', '212229', '212236', '212267', '212270', '212280', '212288', '212299', '212353', '212361', '212370', '212371', '212440', '212492', '212500', '212520', '212540', '212570', '212600', '212609', '212611', '212621', '212631', '212649', '212709', '212710', '212718', '212800', '212845', '212870', '212880', '212900', '212912', '213024', '213055', '213057', '213060', '213069', '213078', '213086', '213093', '213095', '213096', '213112', '213120', '213121', '213139', '213154', '213158', '213169', '213212', '213229', '213241', '213252', '213263', '213265', '213283', '213315', '213333', '213373', '213396', '213431', '213455', '213463', '213470', '213492', '213497', '213510', '213556', '213568', '213574', '213596', '213620', '213636', '213662', '213663 ...

# %% [markdown]
# ## Section 3: Payroll

# %% [markdown]
# ### Context
#
# A startup decides to avoid hiring regular employees for now. Instead, they have been engaging consultants and interns to support them in their current operations. There are not a lot of people, but preparation is tedious.
#
# All consultants and interns get paid at the end of the month.
#
# Interns are expected to render 20 hours of work each month. The actual number of hours worked by each intern is then prorated against the monthly fee stated in their contract. For example, if an intern works 20 hours, then the disbursement will be 100%. If another intern works for only 11, the payout will be 11/20 or 55%.
#
# If interns go overtime in the month, they get a premium of 200% on their hourly rate for anything in excess of 20 hours. The hourly rate is computed as follows:
#
# *hourly rate = contracted monthly fee / 20*
#
# The startup works on an honesty system. In lieu of timesheets, each intern is given a link to Google Forms where they specify their temporary company ID and the number of hours they rendered for the month. All entries are then logged in an associated Google Sheets document. Human Resources then is able to export the spreadsheet into a CSV that looks like so (for the month of July, 2021, as contained in the file **./section3/interns-timelog-july-2021.csv**):
#
# ```
# id,hours_rendered
# 2021001,20
# 2021002,17
# 2021003,16
# 2021004,15
# 2021005,16
# 2021006,18
# 2021007,17
# 2021008,17
# 2021009,15
# 2021010,18
# 2021011,16
# 2021012,20
# 2021013,18
# 2021014,22
# 2021015,20
# 2021016,25
# 2021017,20
# 2021018,17
# 2021019,20
# 2021020,18
# ```
#
# At the company's discretion, certain employees are given work-from-home (WFH) privileges. If an intern has been tagged to be given a WFH allowance, an additional P300 is given.
#
# In addition, the intern gets to designate one of two banks (BPI, BDO) for payroll crediting.
#
# The intern masterfile, saved from a central database as csv, is shown below:
#
# ```
# id,bank,account_number,monthly_fee,wfh
# 2021001,BPI,1093 5000 5001,4500,Y
# 2021002,BPI,1093 5000 5002,3500,Y
# 2021003,BPI,1093 5000 5003,4500,Y
# 2021004,BPI,1093 5000 5004,4500,Y
# 2021005,BPI,1093 5000 5005,6000,Y
# 2021006,BPI,1093 5000 5006,4500,Y
# 2021007,BPI,1093 5000 5007,5000,Y
# 2021008,BPI,1093 5000 5008,4500,Y
# 2021009,BPI,1093 5000 5009,4500,N
# 2021010,BPI,1093 5000 5010,6000,N
# 2021011,BPI,1093 5000 5011,4500,N
# 2021012,BPI,1093 5000 5012,3500,N
# 2021013,BPI,1093 5000 5013,4500,N
# 2021014,BPI,1093 5000 5014,4500,N
# 2021015,BPI,1093 5000 5015,5000,Y
# 2021016,BPI,1093 5000 5016,4500,Y
# 2021017,BPI,1093 5000 5017,6000,Y
# 2021018,BPI,1093 5000 5018,3500,Y
# 2021019,BPI,1093 5000 5019,4500,Y
# 2021020,BPI,1093 5000 5020,4500,Y
# ```
#
# Consultants are paid in full (with no accounting for time); however, their take home pay is their contracted monthly fee less 10%. For example, if one consultant's gross pay is P100,000, the amount to be disbursed is P100,000 less 10% = P90,000. For another consultant that insists on P100,000 as net amount, it will be the company's burden to shoulder the taxes; this arrangement is commonly known as "grossing up". In the case of gross-up, if the disbursement needs to preserve P100,000.00, the contracted monthly fee is P111,111.11.
#
# Similar to interns, certain consultants are provided WFH allowance.
#
# The consultant masterlist is shown below:
#
# ```
# tin,bank,account_number,monthly_fee,wfh
# 151-500-200-000,BPI,1093 5000 6001,100000,Y
# 151-500-201-000,BPI,1093 5000 6002,50000,Y
# 151-500-202-000,BDO,0078 0000 0001,111111.11,Y
# 151-500-203-000,BPI,1093 5000 6004,100000,Y
# 151-500-204-000,BPI,1093 5000 6005,65000,Y
# 151-500-205-000,BPI,1093 5000 6006,130000,Y
# 151-500-206-000,BDO,0078 0000 0002,50000,Y
# 151-500-207-000,BDO,0078 0000 0003,45000,Y
# 151-500-208-000,BPI,1093 5000 6007,45000,N
# 151-500-209-000,BPI,1093 5000 6008,60000,N
# 151-500-210-000,BPI,1093 5000 6009,45000,N
# ```

# %% [markdown]
# ### 3.1

# %% [markdown]
# #### 3.1.1
#
# Write a function **get_utilization** with an argument **hours_rendered** and returns utilization (not percentage).

# %%
# CODE CELL

# CODE START
def get_utilization(hours_rendered):
    utilization = 0
    utilization += (hours_rendered/20)
    return(utilization)
    pass
# CODE END

# %% [markdown]
# #### 3.1.2
#
# Write a function **get_pay** with four arguments: **monthly_fee**, **hours_rendered**, **overtime**, and **wfh_allowance**. It then returns the computed takehome pay as float.
#
# This function will presumably call **get_utilization**.

# %%
# CODE CELL

# CODE START
def get_pay(monthly_fee, hours_rendered, overtime_pay, wfh_allowance):
    total_pay = overtime_pay + wfh_allowance 
    
    # for base pay
    if get_utilization >= 1:
        total_pay += (monthly_fee)
    else:
        total_pay += (monthly_fee * get_utilization)
    
    return(float(total_pay))
    pass
# CODE END

# %% [markdown]
# #### 3.1.3
#
# Write a function **get_overtime_pay** that accepts **hours_rendered** and **monthly_fee** as parameters and then returns the amount of overtime to credit to the intern.

# %%
# CODE CELL

# CODE START
def get_overtime_pay(monthly_fee,hours_rendered):
    ot_pay = 0
    
    if hours_rendered > 20:
        ot_pay += (hours_rendered - 20)*(2*(monthly_fee/20))
    else:
        pass
    return(ot_pay)
    pass
# CODE END

# %% [markdown]
# You may run the cell below to test your code.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it!

# Expected output: 2250.0
get_overtime_pay(4500,25)
# Out:
# 2250.0

# %% [markdown]
# ### 3.2: For Interns

# %% [markdown]
# #### 3.2.1
#
# Create a list variable named `raw_log` that contains dictionaries (or ordered dictionaries if you use the DictReader method of the Python csv module) for each entry in the time-and-attendance log file **./section3/interns-timelogs-july2021.csv**.

# %%
# CODE CELL
import csv

# CODE START
raw_log = []
with open ("./section3/interns-timelogs-july2021.csv","r") as csvfile:
    csvreader = csv.DictReader(csvfile)
    
    for row in csvreader:
        raw_log.append(row)
# CODE END
        
# sample dump of raw_log in interactive mode
raw_log
# Out:
# [{'id': '2021001', 'hours_rendered': '20'},
#  {'id': '2021002', 'hours_rendered': '17'},
#  {'id': '2021003', 'hours_rendered': '16'},
#  {'id': '2021004', 'hours_rendered': '15'},
#  {'id': '2021005', 'hours_rendered': '16'},
#  {'id': '2021006', 'hours_rendered': '18'},
#  {'id': '2021007', 'hours_rendered': '17'},
#  {'id': '2021008', 'hours_rendered': '17'},
#  {'id': '2021009', 'hours_rendered': '15'},
#  {'id': '2021010', 'hours_rendered': '18'},
#  {'id': '2021011', 'hours_rendered': '16'},
#  {'id': '2021012', 'hours_rendered': '20'},
#  {'id': '2021013', 'hours_rendered': '18'},
#  {'id': '2021014', 'hours_rendered': '22'},
#  {'id': '2021015', 'hours_rendered': '20'},
#  {'id': '2021016', 'hours_rendered': '25'},
#  {'id': '2021017', 'hours_rendered': '20'},
#  {'id': '2021018', 'hours_rendered': '17'},
#  {'id': '2021019', 'hours_rendered': '20'},
#  {'id': '2021020', 'hours_rendered': '18'}]

# %% [markdown]
# #### 3.2.2
#
# To retrieve details about individual interns quickly, it's best that we store intern data in a dictionary. This way, we simply lookup the details of the intern by key (in this case, the **id**).
#
# Create a dictionary variable named **interns_master_dict** that contains dictionaries for each entry in the intern master file file **./section3/interns-masterlist.csv**.

# %%
# CODE CELL

# CODE START
interns_master_dict = {}

with open ("./section3/interns_masterlist.csv", newline = "") as csvfile:
    csvreader = csv.DictReader(csvfile)

    for line in csvreader:
        interns_master_dict[line['id']] = {'bank':line['bank'],'account_number':line['account_number'],'monthly_fee':line['monthly_fee'],'wfh':line['wfh']}
# CODE END

# sample dump of raw_log in interactive mode
interns_master_dict
# Out:
# {'2021001': {'bank': 'BPI',
#   'account_number': '1093 5000 5001',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021002': {'bank': 'BPI',
#   'account_number': '1093 5000 5002',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021003': {'bank': 'BPI',
#   'account_number': '1093 5000 5003',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021004': {'bank': 'BPI',
#   'account_number': '1093 5000 5004',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021005': {'bank': 'BPI',
#   'account_number': '1093 5000 5005',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021006': {'bank': 'BPI',
#   'account_number': '1093 5000 5006',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021007': {'bank': 'BPI',
#   'account_number': '1093 5000 5007',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021008': {'bank': 'BPI',
#   'account_number': '1093 5000 5008',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021009': {'bank': 'BPI',
#   'account_number': '1093 5000 5009',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021010': {'bank': 'BPI',
#   'account_number': '1093 5000 5010',
#   'monthly_fee': '6000',
#   'wfh': 'N'},
#  '2021011': {'bank': 'BPI',
#   'account_number': '1093 5000 5011',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021012': {'bank': 'BPI',
#   'account_number': '1093 5000 5012',
#   'monthly_fee': '3500',
#   'wfh': 'N'},
#  '2021013': {'bank': 'BPI',
#   'account_number': '1093 5000 5013',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021014': {'bank': 'BPI',
#   'account_number': '1093 5000 5014',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021015': {'bank': 'BPI',
#   'account_number': '1093 5000 5015',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021016': {'bank': 'BPI',
#   'account_number': '1093 5000 5016',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021017': {'bank': 'BPI',
#   'account_number': '1093 5000 5017',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021018': {'bank': 'BPI',
#   'account_number': '1093 5000 5018',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021019': {'bank': 'BPI',
#   'account_number': '1093 5000 5019',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021020': {'bank': 'BPI',
#   'account_number': '1093 5000 5020',
#   'monthly_fee': '4500',
#   'wfh': 'Y'}}

# %% [markdown]
# #### 3.2.3
#
# Create a new list variable **interns_payroll** based on raw_logs but with an additional key takehome_pay for each dictionary entry.

# %%
# CODE CELL

# CODE START
interns_payroll = raw_log

for row in interns_payroll:
    id_number = row['id']
    monthly_fee = int(interns_master_dict[id_number]['monthly_fee'])
    hours_rendered = int(row['hours_rendered'])
    wfh_allowance_amount = 300

    row['monthly_fee'] = (monthly_fee)
    if get_utilization(hours_rendered) > int(1):
        row['prorated_pay'] = (monthly_fee)
    else:
        row['prorated_pay'] = (get_utilization(hours_rendered) * int(monthly_fee))  
    row['overtime_pay'] = get_overtime_pay(monthly_fee, hours_rendered)
    if interns_master_dict[id_number]['wfh'] == 'Y':
        row['wfh_allowance'] = wfh_allowance_amount
        row['takehome_pay'] = (row['prorated_pay'] + row['overtime_pay'] + row['wfh_allowance'])
    else:
        row['takehome_pay'] = (row['prorated_pay'] + row['overtime_pay'])
# CODE END
                 
# sample dump of payroll in interactive mode
interns_payroll
# Out:
# [{'id': '2021001',
#   'hours_rendered': '20',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021002',
#   'hours_rendered': '17',
#   'monthly_fee': 3500,
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021003',
#   'hours_rendered': '16',
#   'monthly_fee': 4500,
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3900.0},
#  {'id': '2021004',
#   'hours_rendered': '15',
#   'monthly_fee': 4500,
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3675.0},
#  {'id': '2021005',
#   'hours_rendered': '16',
#   'monthly_fee': 6000,
#   'prorated_pay': 4800.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5100.0},
#  {'id': '2021006',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0},
#  {'id': '2021007',
#   'hours_rendered': '17',
#   'monthly_fee': 5000,
#   'prorated_pay': 4250.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4550.0},
#  {'id': '2021008',
#   'hours_rendered': '17',
#   'monthly_fee': 4500,
#   'prorated_pay': 3825.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4125.0},
#  {'id': '2021009',
#   'hours_rendered': '15',
#   'monthly_fee': 4500,
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0,
#   'takehome_pay': 3375.0},
#  {'id': '2021010',
#   'hours_rendered': '18',
#   'monthly_fee': 6000,
#   'prorated_pay': 5400.0,
#   'overtime_pay': 0,
#   'takehome_pay': 5400.0},
#  {'id': '2021011',
#   'hours_rendered': '16',
#   'monthly_fee': 4500,
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0,
#   'takehome_pay': 3600.0},
#  {'id': '2021012',
#   'hours_rendered': '20',
#   'monthly_fee': 3500,
#   'prorated_pay': 3500.0,
#   'overtime_pay': 0,
#   'takehome_pay': 3500.0},
#  {'id': '2021013',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0,
#   'takehome_pay': 4050.0},
#  {'id': '2021014',
#   'hours_rendered': '22',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500,
#   'overtime_pay': 900.0,
#   'takehome_pay': 5400.0},
#  {'id': '2021015',
#   'hours_rendered': '20',
#   'monthly_fee': 5000,
#   'prorated_pay': 5000.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5300.0},
#  {'id': '2021016',
#   'hours_rendered': '25',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500,
#   'overtime_pay': 2250.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 7050.0},
#  {'id': '2021017',
#   'hours_rendered': '20',
#   'monthly_fee': 6000,
#   'prorated_pay': 6000.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 6300.0},
#  {'id': '2021018',
#   'hours_rendered': '17',
#   'monthly_fee': 3500,
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021019',
#   'hours_rendered': '20',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021020',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0}]

# %% [markdown]
# #### 3.2.4
#
# Looping through the new list variable **payroll**, generate an intern payslip print spool file for the month of July. The time logs (as illustrated above) may be found in the file **./section3/interns-timelog-july2021.csv**.
#
# The output must be saved in a file named **./output/interns-payslips-july2021.txt**. The output looks like the following:
#
# ```
# Payroll Date   : July 31, 2021
# ID             : 2021001
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021002
# Monthly Fee       : 3500
# ------------------------------
# Hours Rendered : 17
# ------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021013
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# Takehome Pay   : 4050.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021014
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 22
# ------------------------------
# Prorated Pay   : 4950.0
# Overtime Pay   : 900.0
# Takehome Pay   : 5400.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021019
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021020
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0
#
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2020
# ID             : 2021009
# Base Pay       : 4,500
# ------------------------------
# Hours Rendered : 15
# Takehome Pay   : 3,375.00
# ...
#
# ```
#
# **VERY IMPORTANT:** If the intern does not have a WFH allowance arrangement, **DO NOT** print out the line 'WFH Allowance'!!! The company does not want interns to ask about that if they see that line since it will open a can of worms.

# %%
# CODE CELL
import csv

filename = "./output/interns-payslips-july2021.txt"
payroll_run_date = "July 31, 2021"
# CODE START
index = 0
payroll = """
"""

for person in interns_payroll:
    payroll += f"Payroll Date\t: {payroll_run_date}\n"
    payroll += f"ID\t\t: {interns_payroll[index]['id']}\n"
    payroll += f"Monthly Fee\t: {interns_payroll[index]['monthly_fee']}\n"
    payroll += "------------------------------\n"
    payroll += f"Hours Rendered\t: {interns_payroll[index]['hours_rendered']}\n"
    payroll += "------------------------------\n"
    payroll += f"Prorated Pay\t: {interns_payroll[index]['prorated_pay']}\n"
    payroll += f"Overtime Pay\t: {interns_payroll[index]['overtime_pay']}\n"
    if interns_master_dict[id_number]['wfh'] == 'Y':
        payroll += f"WFH Allowance\t: {wfh_allowance_amount}\n"
    else:
        pass
    payroll += f"Takehome Pay\t: {interns_payroll[index]['takehome_pay']}\n"
    payroll += "\n"
    payroll += "------------------------------\n"
    index += 1

print(payroll)
# Writing txt
with open(filename, 'w') as f:
    f.write(payroll)

# CODE END
# Out:
# Payroll Date	: July 31, 2021
# ID		: 2021001
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021002
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021003
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3900.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021004
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 15
# ------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3675.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021005
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 4800.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5100.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021006
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021007
# Monthly Fee	: 5000
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 4250.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4550.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021008
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 3825.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4125.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021009
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 15
# ------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3375.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021010
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 5400.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5400.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021011
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3600.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021012
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 3500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3500.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021013
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4050.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021014
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 22
# ------------------------------
# Prorated Pay	: 4500
# Overtime Pay	: 900.0
# WFH Allowance	: 300
# Takehome Pay	: 5400.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021015
# Monthly Fee	: 5000
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 5000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5300.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021016
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 25
# ------------------------------
# Prorated Pay	: 4500
# Overtime Pay	: 2250.0
# WFH Allowance	: 300
# Takehome Pay	: 7050.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021017
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 6000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 6300.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021018
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021019
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021020
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0
#
# ------------------------------

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

# See the output of your file
# !cat ./output/interns-payslips-july2021.txt
# Out:
# Payroll Date	: July 31, 2021
# ID		: 2021001
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021002
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021003
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3900.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021004
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 15
# ------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3675.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021005
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 4800.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5100.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021006
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021007
# Monthly Fee	: 5000
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 4250.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4550.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021008
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 3825.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4125.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021009
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 15
# ------------------------------
# Prorated Pay	: 3375.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3375.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021010
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 5400.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5400.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021011
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 16
# ------------------------------
# Prorated Pay	: 3600.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3600.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021012
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 3500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3500.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021013
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4050.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021014
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 22
# ------------------------------
# Prorated Pay	: 4500
# Overtime Pay	: 900.0
# WFH Allowance	: 300
# Takehome Pay	: 5400.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021015
# Monthly Fee	: 5000
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 5000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 5300.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021016
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 25
# ------------------------------
# Prorated Pay	: 4500
# Overtime Pay	: 2250.0
# WFH Allowance	: 300
# Takehome Pay	: 7050.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021017
# Monthly Fee	: 6000
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 6000.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 6300.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021018
# Monthly Fee	: 3500
# ------------------------------
# Hours Rendered	: 17
# ------------------------------
# Prorated Pay	: 2975.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 3275.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021019
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 20
# ------------------------------
# Prorated Pay	: 4500.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4800.0
#
# ------------------------------
# Payroll Date	: July 31, 2021
# ID		: 2021020
# Monthly Fee	: 4500
# ------------------------------
# Hours Rendered	: 18
# ------------------------------
# Prorated Pay	: 4050.0
# Overtime Pay	: 0
# WFH Allowance	: 300
# Takehome Pay	: 4350.0
#
# ------------------------------

# %% [markdown]
# ### 3.3: For Consultants

# %% [markdown]
# Create a regular CSV named **./output/consultants_payouts_july2021.csv** containing consultant payout amounts. Use **./section3/consultants_masterlist.csv** as basis for the amounts, then don't forget to deduct 10% withholding tax.
#
# ```
# tin,net_pay
# 151-500-200-000,90000.00
# ...
# 151-500-202-000,100000.00
# ...
#
# ```

# %% [markdown]
# Create a dictionary **consultants_master_dict** containing lookups for consultants.

# %%
# CODE CELL

consultants_master_dict = {}
# CODE START
with open ('./section3/consultants_masterlist.csv', newline = '') as csvfile:
    csvreader = csv.DictReader(csvfile)
    
    for line in csvreader:
        consultants_master_dict[line['tin']] = {'bank':line['bank'],'account_number':line['account_number']}
# CODE END
consultants_master_dict
# Out:
# {'151-500-200-000': {'bank': 'BPI', 'account_number': '1093 5000 6001'},
#  '151-500-201-000': {'bank': 'BPI', 'account_number': '1093 5000 6002'},
#  '151-500-202-000': {'bank': 'BDO', 'account_number': '0078 0000 0001'},
#  '151-500-203-000': {'bank': 'BPI', 'account_number': '1093 5000 6004'},
#  '151-500-204-000': {'bank': 'BPI', 'account_number': '1093 5000 6005'},
#  '151-500-205-000': {'bank': 'BPI', 'account_number': '1093 5000 6006'},
#  '151-500-206-000': {'bank': 'BDO', 'account_number': '0078 0000 0002'},
#  '151-500-207-000': {'bank': 'BDO', 'account_number': '0078 0000 0003'},
#  '151-500-208-000': {'bank': 'BPI', 'account_number': '1093 5000 6007'},
#  '151-500-209-000': {'bank': 'BPI', 'account_number': '1093 5000 6008'},
#  '151-500-210-000': {'bank': 'BPI', 'account_number': '1093 5000 6009'}}

# %% [markdown]
# Unlike the interns, we don't need to give consultants payslips. However, it would be easier to run "payroll" for consultants and store the results in a staging file. Run the consultants' "payroll" by keeping the results in a list variable called **consultants_payroll**. Each element of this list is based on a corresponding role in **./section3/consultants_masterlist.csv**. To make it easier, create a **consultants_fees** list variable by reading from this file.
#
# Then, generate a consultant payout file named **./output/consultants_payouts_july2021.csv**.

# %%
# CODE CELL
consultants_fees = []

input_file = "./section3/consultants_masterlist.csv"
# CODE START
with open (input_file, newline = '') as csvfile:
    csvreader = csv.DictReader(csvfile)
    
    for row in csvreader:
        consultants_fees.append({'tin':row['tin'], 'bank':row['bank'], 'account_number':row['account_number'], 'monthly_fee':row['monthly_fee'], 'wfh':row['wfh']})
# CODE END

# dump output
consultants_fees
# Out:
# [{'tin': '151-500-200-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6001',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-201-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-202-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0001',
#   'monthly_fee': '111111.11',
#   'wfh': 'Y'},
#  {'tin': '151-500-203-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6004',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-204-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6005',
#   'monthly_fee': '65000',
#   'wfh': 'Y'},
#  {'tin': '151-500-205-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6006',
#   'monthly_fee': '130000',
#   'wfh': 'Y'},
#  {'tin': '151-500-206-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-207-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0003',
#   'monthly_fee': '45000',
#   'wfh': 'Y'},
#  {'tin': '151-500-208-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6007',
#   'monthly_fee': '45000',
#   'wfh': 'N'},
#  {'tin': '151-500-209-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6008',
#   'monthly_fee': '60000',
#   'wfh': 'N'},
#  {'tin': '151-500-210-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6009',
#   'monthly_fee': '45000',
#   'wfh': 'N'}]

# %%
# CODE CELL
consultants_payroll = []

# CODE START
for account in consultants_fees:
    consultants_payroll.append({'tin':account['tin'],'net_pay':(float(account['monthly_fee'])*0.9)})

with open ('./output/consultants_payouts_july2021.csv', 'w') as csvfile:
    csvwriter = csv.writer (csvfile)
    csvwriter.writerow(['tin','net_pay'])
    for row in consultants_payroll:
        csvwriter.writerow([row['tin'],row['net_pay']])
# CODE END

# sample dump of raw_log in interactive mode
consultants_payroll
# Out:
# [{'tin': '151-500-200-000', 'net_pay': 90000.0},
#  {'tin': '151-500-201-000', 'net_pay': 45000.0},
#  {'tin': '151-500-202-000', 'net_pay': 99999.999},
#  {'tin': '151-500-203-000', 'net_pay': 90000.0},
#  {'tin': '151-500-204-000', 'net_pay': 58500.0},
#  {'tin': '151-500-205-000', 'net_pay': 117000.0},
#  {'tin': '151-500-206-000', 'net_pay': 45000.0},
#  {'tin': '151-500-207-000', 'net_pay': 40500.0},
#  {'tin': '151-500-208-000', 'net_pay': 40500.0},
#  {'tin': '151-500-209-000', 'net_pay': 54000.0},
#  {'tin': '151-500-210-000', 'net_pay': 40500.0}]

# %% [markdown]
# To check if your payout file contents are correct, run `cat` (if using MacOS) or `type` (if using Windows). Don't forget the "!" character before the command. Replace `cat` with `type` if you are on Windows.

# %%
# !cat ./output/consultants_payouts_july2021.csv
# Out:
# tin,net_pay
# 151-500-200-000,90000.0
# 151-500-201-000,45000.0
# 151-500-202-000,99999.999
# 151-500-203-000,90000.0
# 151-500-204-000,58500.0
# 151-500-205-000,117000.0
# 151-500-206-000,45000.0
# 151-500-207-000,40500.0
# 151-500-208-000,40500.0
# 151-500-209-000,54000.0
# 151-500-210-000,40500.0

# %% [markdown]
# ### 3.4: Bank Credit Advise

# %% [markdown]
# **B. Bank Credit Advise**
#
# Generate a credit advise file each for BPI and BDO covering interns and consultants. The files must be named **./output/su-bpi-payment-advise.csv** and **./output/su-bdo-payment-advise.csv** respectively and should look like the following:
#
# ```
# account_number,amount
# 109350005001,4800.0
# 109350005002,3275.0
# ...
# 109350005003,3375.0
# ...
# 109350006001,9000
# ```

# %%
# CODE CELL
bpi_advise = []
bdo_advise = []

# CODE START
# For interns
index = 0
for row in interns_master_dict:
    if (interns_master_dict[row]['bank'] == 'BPI'):
        bpi_advise.append({'account_number':interns_master_dict[row]['account_number'], 'amount':interns_payroll[index]['takehome_pay']})
    else:
        bdo_advise.append({'account_number':interns_master_dict[row]['account_number'], 'amount':interns_payroll[index]['takehome_pay']})
    index += 1

# For consultants
index = 0
for row in consultants_master_dict:
    if (consultants_master_dict[row]['bank'] == 'BPI'):
        bpi_advise.append({'account_number':consultants_master_dict[row]['account_number'], 'amount':consultants_payroll[index]['net_pay']})
    else:
        bdo_advise.append({'account_number':consultants_master_dict[row]['account_number'], 'amount':consultants_payroll[index]['net_pay']})
    index += 1
    
# Writing csv
with open ('./output/su-bpi-payment-advise.csv', 'w') as bpi_csvfile:
    csvwriter1 = csv.writer (bpi_csvfile)
    csvwriter1.writerow(['account_number','amount'])
    for row in bpi_advise:
        csvwriter1.writerow([row['account_number'],row['amount']])

with open ('./output/su-bdo-payment-advise.csv', 'w') as bdo_csvfile:
    csvwriter2 = csv.writer (bdo_csvfile)
    csvwriter2.writerow(['account_number','amount'])
    for row in bdo_advise:
        csvwriter2.writerow([row['account_number'],row['amount']])        
# CODE END

# %%
bpi_advise
# Out:
# [{'account_number': '1093 5000 5001', 'amount': 4800.0},
#  {'account_number': '1093 5000 5002', 'amount': 3275.0},
#  {'account_number': '1093 5000 5003', 'amount': 3900.0},
#  {'account_number': '1093 5000 5004', 'amount': 3675.0},
#  {'account_number': '1093 5000 5005', 'amount': 5100.0},
#  {'account_number': '1093 5000 5006', 'amount': 4350.0},
#  {'account_number': '1093 5000 5007', 'amount': 4550.0},
#  {'account_number': '1093 5000 5008', 'amount': 4125.0},
#  {'account_number': '1093 5000 5009', 'amount': 3375.0},
#  {'account_number': '1093 5000 5010', 'amount': 5400.0},
#  {'account_number': '1093 5000 5011', 'amount': 3600.0},
#  {'account_number': '1093 5000 5012', 'amount': 3500.0},
#  {'account_number': '1093 5000 5013', 'amount': 4050.0},
#  {'account_number': '1093 5000 5014', 'amount': 5400.0},
#  {'account_number': '1093 5000 5015', 'amount': 5300.0},
#  {'account_number': '1093 5000 5016', 'amount': 7050.0},
#  {'account_number': '1093 5000 5017', 'amount': 6300.0},
#  {'account_number': '1093 5000 5018', 'amount': 3275.0},
#  {'account_number': '1093 5000 5019', 'amount': 4800.0},
#  {'account_number': '1093 5000 5020', 'amount': 4350.0},
#  {'account_number': '1093 5000 6001', 'amount': 90000.0},
#  {'account_number': '1093 5000 6002', 'amount': 45000.0},
#  {'account_number': '1093 5000 6004', 'amount': 90000.0},
#  {'account_number': '1093 5000 6005', 'amount': 58500.0},
#  {'account_number': '1093 5000 6006', 'amount': 117000.0},
#  {'account_number': '1093 5000 6007', 'amount': 40500.0},
#  {'account_number': '1093 5000 6008', 'amount': 54000.0},
#  {'account_number': '1093 5000 6009', 'amount': 40500.0}]

# %%
bdo_advise
# Out:
# [{'account_number': '0078 0000 0001', 'amount': 99999.999},
#  {'account_number': '0078 0000 0002', 'amount': 45000.0},
#  {'account_number': '0078 0000 0003', 'amount': 40500.0}]

# %% [markdown]
# To check if your file outputs are correct, run either cat (on MacOS) or type (on Windows) below. Just replace `cat` with `type` if you're using Windows.

# %%
# !cat ./output/su-bpi-payment-advise.csv
# Out:
# account_number,amount
# 1093 5000 5001,4800.0
# 1093 5000 5002,3275.0
# 1093 5000 5003,3900.0
# 1093 5000 5004,3675.0
# 1093 5000 5005,5100.0
# 1093 5000 5006,4350.0
# 1093 5000 5007,4550.0
# 1093 5000 5008,4125.0
# 1093 5000 5009,3375.0
# 1093 5000 5010,5400.0
# 1093 5000 5011,3600.0
# 1093 5000 5012,3500.0
# 1093 5000 5013,4050.0
# 1093 5000 5014,5400.0
# 1093 5000 5015,5300.0
# 1093 5000 5016,7050.0
# 1093 5000 5017,6300.0
# 1093 5000 5018,3275.0
# 1093 5000 5019,4800.0
# 1093 5000 5020,4350.0
# 1093 5000 6001,90000.0
# 1093 5000 6002,45000.0
# 1093 5000 6004,90000.0
# 1093 5000 6005,58500.0
# 1093 5000 6006,117000.0
# 1093 5000 6007,40500.0
# 1093 5000 6008,54000.0
# 1093 5000 6009,40500.0

# %%
# !cat ./output/su-bdo-payment-advise.csv
# Out:
# account_number,amount
# 0078 0000 0001,99999.999
# 0078 0000 0002,45000.0
# 0078 0000 0003,40500.0
